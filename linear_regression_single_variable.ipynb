# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("data_test.csv")

# %%
df
# Out:
#     year        income
# 0   1970   3399.299037
# 1   1971   3768.297935
# 2   1972   4251.175484
# 3   1973   4804.463248
# 4   1974   5576.514583
# 5   1975   5998.144346
# 6   1976   7062.131392
# 7   1977   7100.126170
# 8   1978   7247.967035
# 9   1979   7602.912681
# 10  1980   8355.968120
# 11  1981   9434.390652
# 12  1982   9619.438377
# 13  1983  10416.536590
# 14  1984  10790.328720
# 15  1985  11018.955850
# 16  1986  11482.891530
# 17  1987  12974.806620
# 18  1988  15080.283450
# 19  1989  16426.725480
# 20  1990  16838.673200
# 21  1991  17266.097690
# 22  1992  16412.083090
# 23  1993  15875.586730
# 24  1994  15755.820270
# 25  1995  16369.317250
# 26  1996  16699.826680
# 27  1997  17310.757750
# 28  1998  16622.671870
# 29  1999  17581.024140
# 30  2000  18987.382410
# 31  2001  18601.397240
# 32  2002  19232.175560
# 33  2003  22739.426280
# 34  2004  25719.147150
# 35  2005  29198.055690
# 36  2006  32738.262900
# 37  2007  36144.481220
# 38  2008  37446.486090
# ...

# %%
df.head()
# Out:
#    year       income
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
# 4  1974  5576.514583

# %%
df.tail()
# Out:
#     year       income
# 42  2012  42665.25597
# 43  2013  42676.46837
# 44  2014  41039.89360
# 45  2015  35175.18898
# 46  2016  34229.19363

# %%
# %matplotlib inline
plt.scatter(df.year,df.income,color='blue',marker='+')

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('income')
plt.scatter(df.year,df.income,color='blue',marker='+')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['year']],df.income)
# Out:
# LinearRegression()

# %%
reg.predict([[1980]])
# Out:
# C:\Users\Sarthak\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([8150.09108551])

# %%
reg.coef_
# Out:
# array([828.46507522])

# %%
reg.intercept_
# Out:
# -1632210.7578554575

# %%
828.46507522*1980+(-1632210.7578554575)
# Out:
# 8150.091080142651

# %%
reg.predict(df)
# Out:
# C:\Users\Sarthak\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - income
#
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 reg.predict(df)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_base.py:386, in LinearModel.predict(self, X)
#     372 def predict(self, X):
#     373     """
#     374     Predict using the linear model.
#     375
#    (...)
#     384         Returns predicted values.
#     385     """
# --> 386     return self._decision_function(X)
#
# ...

# %%
d=pd.read_csv("data_year.csv")

# %%
d
# Out:
#     year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1985
# 16  1986
# 17  1987
# 18  1988
# 19  1989
# 20  1990
# 21  1991
# 22  1992
# 23  1993
# 24  1994
# 25  1995
# 26  1996
# 27  1997
# 28  1998
# 29  1999
# 30  2000
# 31  2001
# 32  2002
# 33  2003
# 34  2004
# 35  2005
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016

# %%
p=reg.predict(d)

# %%
p
# Out:
# array([ -134.55966672,   693.9054085 ,  1522.37048373,  2350.83555895,
#         3179.30063417,  4007.7657094 ,  4836.23078462,  5664.69585984,
#         6493.16093506,  7321.62601029,  8150.09108551,  8978.55616073,
#         9807.02123595, 10635.48631118, 11463.9513864 , 12292.41646162,
#        13120.88153685, 13949.34661207, 14777.81168729, 15606.27676251,
#        16434.74183774, 17263.20691296, 18091.67198818, 18920.1370634 ,
#        19748.60213863, 20577.06721385, 21405.53228907, 22233.9973643 ,
#        23062.46243952, 23890.92751474, 24719.39258996, 25547.85766519,
#        26376.32274041, 27204.78781563, 28033.25289085, 28861.71796608,
#        29690.1830413 , 30518.64811652, 31347.11319175, 32175.57826697,
#        33004.04334219, 33832.50841741, 34660.97349264, 35489.43856786,
#        36317.90364308, 37146.3687183 , 37974.83379353])

# %%
d['income']=p

# %%
d
# Out:
#     year        income
# 0   1970   -134.559667
# 1   1971    693.905409
# 2   1972   1522.370484
# 3   1973   2350.835559
# 4   1974   3179.300634
# 5   1975   4007.765709
# 6   1976   4836.230785
# 7   1977   5664.695860
# 8   1978   6493.160935
# 9   1979   7321.626010
# 10  1980   8150.091086
# 11  1981   8978.556161
# 12  1982   9807.021236
# 13  1983  10635.486311
# 14  1984  11463.951386
# 15  1985  12292.416462
# 16  1986  13120.881537
# 17  1987  13949.346612
# 18  1988  14777.811687
# 19  1989  15606.276763
# 20  1990  16434.741838
# 21  1991  17263.206913
# 22  1992  18091.671988
# 23  1993  18920.137063
# 24  1994  19748.602139
# 25  1995  20577.067214
# 26  1996  21405.532289
# 27  1997  22233.997364
# 28  1998  23062.462440
# 29  1999  23890.927515
# 30  2000  24719.392590
# 31  2001  25547.857665
# 32  2002  26376.322740
# 33  2003  27204.787816
# 34  2004  28033.252891
# 35  2005  28861.717966
# 36  2006  29690.183041
# 37  2007  30518.648117
# 38  2008  31347.113192
# ...

# %%
d.to_csv('data_prediction.csv',index=False)

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('income')
plt.scatter(d.year,d.income,color='red',marker='+') #predicted income using regression
plt.scatter(df.year,df.income,color='blue',marker='+') #original values
#plt.plot(d.year,reg.predict(d[['income']]))

# %%
d
# Out:
#     year        income
# 0   1970   -134.559667
# 1   1971    693.905409
# 2   1972   1522.370484
# 3   1973   2350.835559
# 4   1974   3179.300634
# 5   1975   4007.765709
# 6   1976   4836.230785
# 7   1977   5664.695860
# 8   1978   6493.160935
# 9   1979   7321.626010
# 10  1980   8150.091086
# 11  1981   8978.556161
# 12  1982   9807.021236
# 13  1983  10635.486311
# 14  1984  11463.951386
# 15  1985  12292.416462
# 16  1986  13120.881537
# 17  1987  13949.346612
# 18  1988  14777.811687
# 19  1989  15606.276763
# 20  1990  16434.741838
# 21  1991  17263.206913
# 22  1992  18091.671988
# 23  1993  18920.137063
# 24  1994  19748.602139
# 25  1995  20577.067214
# 26  1996  21405.532289
# 27  1997  22233.997364
# 28  1998  23062.462440
# 29  1999  23890.927515
# 30  2000  24719.392590
# 31  2001  25547.857665
# 32  2002  26376.322740
# 33  2003  27204.787816
# 34  2004  28033.252891
# 35  2005  28861.717966
# 36  2006  29690.183041
# 37  2007  30518.648117
# 38  2008  31347.113192
# ...

# %%
reg.predict([[2020]])
# Out:
# C:\Users\Sarthak\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
reg.predict([[2020]])
# Out:
# C:\Users\Sarthak\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
