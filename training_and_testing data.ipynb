# %%
import pandas as pd
import numpy as np
import math
import sklearn
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('carprices.csv')
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
# %matplotlib inline

# %%
milvssp=plt.scatter(df['Mileage'],df['Sell Price($)'],color='red',marker='+')

# %% [markdown]
#  plt.scatter(df['Age(yrs)'],df['Sell Price($)'],marker='+')

# %%
plt.scatter(df['Age(yrs)'],df['Sell Price($)'],marker='+')

# %%
x=df[['Mileage','Age(yrs)']]
y=df[['Sell Price($)']]

# %%
x
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
y
# Out:
#     Sell Price($)
# 0           18000
# 1           34000
# 2           26100
# 3           40000
# 4           31500
# 5           26750
# 6           32000
# 7           19300
# 8           12000
# 9           22000
# 10          18700
# 11          19500
# 12          26000
# 13          27500
# 14          19400
# 15          35000
# 16          35500
# 17          19700
# 18          12800
# 19          28200

# %%
from sklearn.model_selection import train_test_split
#lib used for training and testing

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
#train test split returns 4 parameters and test size is given,ie,0.2 is the
#ratio of data to be tested on.here 0.2 means 20% of the data out of 100% of it

# %%
len(x_train),len(x_test)
#out length of the overall dataset is 20 an hence 80% is 16 and 20% is 
#4 which complies with the previous argument
# Out:
# (16, 4)

# %%
x_train
# Out:
#     Mileage  Age(yrs)
# 10    83000         7
# 7     72000         6
# 19    52000         5
# 11    79000         7
# 17    69000         5
# 2     57000         5
# 15    25400         3
# 6     52000         5
# 12    59000         5
# 18    87600         8
# 14    82450         7
# 9     67000         6
# 5     59000         5
# 13    58780         4
# 3     22500         2
# 8     91000         8

# %%
#we see it used random samples which is a point to note because random 
#samples are better for prediction and testing as the data is not going 
#to be of order in real world applications

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
x_train
# Out:
#     Mileage  Age(yrs)
# 7     72000         6
# 3     22500         2
# 11    79000         7
# 1     35000         3
# 16    28000         2
# 13    58780         4
# 18    87600         8
# 8     91000         8
# 2     57000         5
# 14    82450         7
# 15    25400         3
# 12    59000         5
# 5     59000         5
# 6     52000         5
# 17    69000         5
# 4     46000         4

# %%
#NOTE-if we use train_test_split again and again the sequence will change 
#as its ordering is always random

# %%
#when we want our training data to be the same we add a random_state parimiter to the train_test_split command
#Random state ensures that the splits that you generate are reproducible.

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)
x_train
# Out:
#     Mileage  Age(yrs)
# 3     22500         2
# 18    87600         8
# 13    58780         4
# 2     57000         5
# 14    82450         7
# 8     91000         8
# 17    69000         5
# 16    28000         2
# 19    52000         5
# 12    59000         5
# 11    79000         7
# 1     35000         3
# 0     69000         6
# 15    25400         3
# 4     46000         4
# 9     67000         6

# %%
from sklearn import linear_model
clf=linear_model.LinearRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
# Out:
# array([[20474.0745775 ],
#        [16352.07892168],
#        [25174.14834912],
#        [27197.42175439]])

# %%
y_test
# Out:
#     Sell Price($)
# 7           19300
# 10          18700
# 5           26750
# 6           32000

# %%
clf.score(x_test,y_test)

#score compares x test values and y test values and predict the accuracy of the model
# Out:
# 0.733233959309014

# %%
#step1:read dataset
#step2:generate x nd y values
#step3:import train_test_splitfrom sklearn.model_selection 
#      model selection is library used for training and testing data
#step4:use train_test_split on x and y and provide the % of data to be used or training and testing using test+size='xyz'
#step5:creating linear regression model over x_train and y_train to predict x_test
#step6:y_test gets updated wrt x_test and hence score method is used to find accuracy of the model

# %%
clf.predict(y_test)
# Out:
# C:\Users\Sarthak\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Sell Price($)
# Feature names seen at fit time, yet now missing:
# - Age(yrs)
# - Mileage
#
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 clf.predict(y_test)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_base.py:386, in LinearModel.predict(self, X)
#     372 def predict(self, X):
#     373     """
#     374     Predict using the linear model.
#     375
#    (...)
#     384         Returns predicted values.
#     385     """
# --> 386     return self._decision_function(X)
#
# ...
